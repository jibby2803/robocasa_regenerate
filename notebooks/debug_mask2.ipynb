# %%
import h5py 
import json

def list_demos(h5_path: str):
    with h5py.File(h5_path, "r") as f:
        g = f.get("data")
        if g is None:
            raise KeyError("Group 'data' not found in HDF5.")
        demos = []
        for k in g.keys():
            if k.startswith("demo_"):
                try:
                    task = json.loads(g[k].attrs['ep_meta'])['lang']
                    # data['data']['demo_1236'].attrs['ep_meta']
                    demos.append((int(k.split("_", 1)[1]), task))
                except ValueError:
                    pass
    # return sorted(demos)
    demos = sorted(demos)
    print(len(demos))
    demos = check_ooi_not_exist(h5_path, demos)
    return demos

def get_ooi_ids(dataset_name, demo_id, num_demo=100):
    ooi_anno_dir = f"/home/binhng/Workspace/robocasa/robocasa/datasets/regenerate/robocasa-{num_demo}demos-5chosen-tasks/ooi_anno/{dataset_name.split('.')[0]}/"
    ooi_files = [
        f"{demo_id.replace('_', '')}_left_element_ooi.json",
        f"{demo_id.replace('_', '')}_right_element_ooi.json",
        f"{demo_id.replace('_', '')}_hand_element_ooi.json"
    ]

    all_ooi_ids = []
    for file in ooi_files:
        try:
            with open(ooi_anno_dir+file, 'r', encoding='utf-8') as f:
                all_ooi_ids += json.load(f)  # parse JSON content from file
        except:
            continue

    all_ooi_ids = list(set(all_ooi_ids))
    print("all_ooi_ids:", all_ooi_ids)
    return all_ooi_ids

def check_ooi_not_exist(h5_path, demos):
    dataset_name = h5_path.split("/")[-1].replace(".hdf5", "")
    num_demos = 100 if "100" in h5_path else 30
    # ooi_anno_dir = "/home/binhng/Workspace/robocasa/robocasa/datasets/regenerate/robocasa-30demos-5chosen-tasks-element/ooi_anno/"
    output = []
    print(demos)
    for demo in demos:
        ooi_ids = get_ooi_ids(dataset_name, f"demo_{demo[0]}", num_demos)
        if len(ooi_ids) == 0:
            output.append(demo)
    return output

# %%
'state'.startswith("state")
# Out:
# True

# %%
# task_name = "CoffeeSetupMug"
task_name = "PnPCabToCounter"
# task_name = "PnPCounterToCab"
# task_name = "TurnOffStove"
# task_name = "TurnOnMicrowave"
h5_path = f"/home/binhng/Workspace/robocasa/robocasa/datasets/regenerate/robocasa-30demos-5chosen-tasks/{task_name}.hdf5"
ooi_not_exist_demos = list_demos(h5_path)
ooi_not_exist_demos
# Out:
# 27
# [(61, 'pick the egg from the cabinet and place it on the counter'), (196, 'pick the mushroom from the cabinet and place it on the counter'), (320, 'pick the jam from the cabinet and place it on the counter'), (328, 'pick the canned food from the cabinet and place it on the counter'), (361, 'pick the tangerine from the cabinet and place it on the counter'), (436, 'pick the squash from the cabinet and place it on the counter'), (453, 'pick the can from the cabinet and place it on the counter'), (522, 'pick the cereal from the cabinet and place it on the counter'), (804, 'pick the onion from the cabinet and place it on the counter'), (825, 'pick the bell pepper from the cabinet and place it on the counter'), (902, 'pick the banana from the cabinet and place it on the counter'), (1181, 'pick the kiwi from the cabinet and place it on the counter'), (1217, 'pick the cupcake from the cabinet and place it on the counter'), (1236, 'pick the jam from the cabinet and place it on the counter'), (1251, 'pick the tangerine from the cabinet and place it on the counter'), (1518, 'pick the lemon from the cabinet and place it on the counter'), (1711, 'pick the bar soap from the cabinet and place it on the counter'), (1801, 'pick the orange from the cabinet and place it on the counter'), (1902, 'pick the can from the cabinet and place it on the counter'), (2127, 'pick the boxed food from the cabinet and place it on the counter'), (2128, 'pick the bar from the cabinet and place it on the counter'), (2157, 'pick the baguette from the cabinet and place it on the counter'), (2274, 'pick the apple from the cabinet and place it on the counter'), (2543, 'pick the jug from the cabinet and place it on the counter'), (2630, 'pick the ketchup from the cabinet and place it on the counter'), (2684, 'pick the bottled water from the cabinet and place it on the counter'), (2995, 'pick the hot dog from the cabinet and place it on the counter')]
# all_ooi_ids: [160, 1448, 80, 250, 62]
# all_ooi_ids: [62, 2317, 1765, 1230]
# all_ooi_ids: [64, 963, 67, 1323, 725, 62]
# all_ooi_ids: [160, 67, 1448, 80, 250, 62]
# all_ooi_ids: [64, 129, 67, 276, 765, 62]
# all_ooi_ids: [1400, 1328, 972, 62]
# all_ooi_ids: [931, 1357, 62, 1287]
# all_ooi_ids: []
# all_ooi_ids: [1400, 1328, 972, 62]
# all_ooi_ids: [64, 129, 276, 765, 62]
# all_ooi_ids: [129, 276, 765, 62]
# all_ooi_ids: [129, 276, 765, 62]
# all_ooi_ids: [523, 916, 62, 575]
# all_ooi_ids: [64, 67, 523, 916, 62, 575]
# all_ooi_ids: [129, 276, 765, 62]
# all_ooi_ids: [523, 526, 916, 62, 575]
# all_ooi_ids: [64, 67, 1765, 1766, 2317, 1230, 62]
# all_ooi_ids: [129, 276, 765, 62]
# all_ooi_ids: [64, 1541, 997, 1159, 62]
# all_ooi_ids: [1541, 997, 1159, 1160, 62]
# all_ooi_ids: [129, 276, 765, 62]
# all_ooi_ids: [523, 917, 62, 575]
# all_ooi_ids: [523, 916, 62, 575]
# all_ooi_ids: [1338, 414, 62, 114]
# all_ooi_ids: [2317, 1230, 1765, 62]
# all_ooi_ids: [62, 1338, 414, 114]
# all_ooi_ids: [931, 1287, 1357, 1358, 62]
# [(522, 'pick the cereal from the cabinet and place it on the counter')]

# %%
"pick the cereal from the cabinet and place it on the counter"

# %%
check_ooi_not_exist
# Out:
# <function __main__.check_ooi_not_exist(h5_path, demos)>
